# %%
import math
import pandas as pd

import matplotlib.pyplot as plt

from PIL import Image
from statsbombpy import sb
from mplsoccer import VerticalPitch

# %%
df = pd.DataFrame(sb.matches(competition_id=43, season_id=106))
pd.set_option('display.max_rows', 100)
df
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 0    3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1    3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2    3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
# 3    3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 4    3857288  2022-11-26  12:00:00.000  International - FIFA World Cup   2022
# 5    3857267  2022-11-29  17:00:00.000  International - FIFA World Cup   2022
# 6    3869321  2022-12-09  21:00:00.000  International - FIFA World Cup   2022
# 7    3857287  2022-11-24  15:00:00.000  International - FIFA World Cup   2022
# 8    3869486  2022-12-10  17:00:00.000  International - FIFA World Cup   2022
# 9    3869685  2022-12-18  17:00:00.000  International - FIFA World Cup   2022
# 10   3857260  2022-11-30  21:00:00.000  International - FIFA World Cup   2022
# ...

# %%
#Get the match ID and sort it by numerical order
df = sb.events(match_id=3869253).sort_values(by=['index'])
df
# Out:
#      50_50 ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                  NaN                     NaN
# 1      NaN                  NaN                     NaN
# 2      NaN                  NaN                     NaN
# 3      NaN                  NaN                     NaN
# 6      NaN                  NaN                     NaN
# ...    ...                  ...                     ...
# 3317   NaN                  NaN                     NaN
# 3595   NaN                  NaN                     NaN
# 1201   NaN                  NaN                     NaN
# 4026   NaN                  NaN                     NaN
# 4027   NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                               NaN              NaN             NaN
# 1                               NaN              NaN             NaN
# 2                               NaN              NaN             NaN
# ...

# %%
#Set up Brazil and Korea customizations
team1 = df[df.team == 'Brazil']
team2 = df[df.team == 'South Korea']

BRAZIL_COLOR = '#FFFF00'
KOREA_COLOR = ' #0000FF'

BRAZIL_TEAM_ID = 781
KOREA_TEAM_ID = 791

# %%
#Remove all pelnaty shootout
df = df[df.period < 5]

# %%
def create_shotmap(team, ax):
    pass

# %%
def create_passnetwork(team, ax):
    pass

# %%
def create_table(team1, team2):
    pass

# %%
def create_xg_flow_chart(df, ax):
    pass

# %%
#Create grid for the axes
fig = plt.figure(figsize=(15,12))

ax1 = fig.add_axes([.225, .775, .15, .15])

ax2 = fig.add_axes([.5, .8, .3, .1])

ax3 = fig.add_axes([.925, .775, .15, .15])

ax4 = fig.add_axes([.15, .25, .3, .5])

ax5 = fig.add_axes([.5, .2, .3, .5])

ax6 = fig.add_axes([.85, .25, .3, .5])

ax7 = fig.add_axes([.2, .05, .2, .2])

ax8 = fig.add_axes([.5, .05, .3, .2])

ax9 = fig.add_axes([.9, .05, .2, .2])
